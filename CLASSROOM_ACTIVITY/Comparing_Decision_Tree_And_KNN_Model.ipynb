# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import pandas as pd

# %%
from sklearn.datasets import load_wine

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.metrics import accuracy_score, mean_squared_error
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# # LOADING DATASET

# %%
wine=load_wine()

# %% [markdown]
# # Input and Output

# %%
x=wine.data

# %%
y=wine.target

# %% [markdown]
# # Train Test Split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# ## Choosing The Model(We are choosing KNN and Decision Tree

# %%
decison_model=DecisionTreeClassifier()
knn_model=KNeighborsClassifier()

# %% [markdown]
# # Train The Model

# %%
decison_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
knn_model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# # Test The Model

# %%
dec_pred=decison_model.predict(x_test)
knn_pred=knn_model.predict(x_test)

# %% [markdown]
# # Accuracy

# %%
print("Decision_Accuracy", accuracy_score(y_test, dec_pred))
print("KNN_Accuracy", accuracy_score(y_test, knn_pred))
# Out:
# Decision_Accuracy 0.9444444444444444
# KNN_Accuracy 0.7222222222222222
