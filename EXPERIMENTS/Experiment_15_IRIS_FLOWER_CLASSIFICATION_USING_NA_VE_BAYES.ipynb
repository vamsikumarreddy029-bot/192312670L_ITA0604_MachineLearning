# %% [markdown]
# # EXPERIMENT NUMBER 15: IRIS FLOWER CLASSIFICATION USING NAÏVE BAYES
#
# **Aim:** To implement Iris Flower Classification using a Naïve Bayes classifier.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

# Load Dataset
iris = load_iris()

X = iris.data
y = iris.target

# Split Dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Train Model
model = GaussianNB()
model.fit(X_train, y_train)

# Prediction
y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))

# New Sample Prediction
sample = [[6.0, 3.0, 4.8, 1.8]]
print("Predicted Flower:", iris.target_names[model.predict(sample)[0]])
# Out:
# Accuracy: 0.9777777777777777
# Predicted Flower: virginica

# %% [markdown]
# ### Result
# The program has been executed and the output is shown above.
